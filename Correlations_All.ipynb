# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Results/hosts_with_distances_cultural_red.csv", index_col=0)
df.head(3)
# Out:
#           host_id                                   host_url host_name  \
# id
# 35797.0    153786   https://www.airbnb.com/users/show/153786      Dici
# 611179.0  1297488  https://www.airbnb.com/users/show/1297488     Petra
# 611337.0  1297488  https://www.airbnb.com/users/show/1297488     Petra
#
#          host_response_rate host_acceptance_rate  host_is_superhost  \
# id
# 35797.0                 NaN                  NaN                  0
# 611179.0               100%                  83%                  1
# 611337.0               100%                  83%                  1
#
#           host_listings_count  host_total_listings_count  \
# id
# 35797.0                     1                          1
# 611179.0                    6                          7
# 611337.0                    6                          7
#
#           d_t_museo_nacional_de_antropologia  d_t_castillo_de_chapultepec  \
# id
# 35797.0                            10.169309                    10.330075
# ...

# %%
print("The dataset contains " + str(df.shape[0]) + " rows and " + str(df.shape[1]) + " columns or attributes" )
# Out:
# The dataset contains 26319 rows and 44 columns or attributes

# %%
df.describe()
# Out:
#             host_id  host_is_superhost  host_total_listings_count  \
# count  2.631900e+04       26319.000000               26318.000000
# mean   1.994842e+08           0.392872                  29.363211
# std    1.683764e+08           0.488398                 104.470173
# min    5.000000e+00           0.000000                   1.000000
# 25%    5.030516e+07           0.000000                   2.000000
# 50%    1.479522e+08           0.000000                   5.000000
# 75%    3.416858e+08           1.000000                  15.000000
# max    5.382907e+08           1.000000                2421.000000
#
#        d_t_museo_nacional_de_antropologia  d_t_castillo_de_chapultepec  \
# count                        26318.000000                 26318.000000
# mean                             5.188730                     4.826912
# std                              4.277762                     4.189960
# min                              0.290477                     0.196516
# ...

# %%
df.dtypes.sort_values(ascending=True)
# Out:
# host_id                                                int64
# host_is_superhost                                      int64
# d_t_museo_diego_rivera                               float64
# d_t_museo_nacional_de_arte                           float64
# d_t_museo_casa_leon_trotsky                          float64
# d_t_cineteca_nacional                                float64
# d_t_museo_franz_mayer                                float64
# d_t_antiguo_colegio_de_san_ildefonso                 float64
# d_t_museo_del_tiempo_tlalpan                         float64
# d_t_monumento_a_la_independencia_(el_angel)          float64
# d_t_sagrario_metropolitano                           float64
# d_t_museo_de_arte_moderno                            float64
# d_t_museo_universitario_arte_contemporaneo_(muac)    float64
# d_t_plaza_de_las_tres_culturas                       float64
# d_t_monumento_a_los_ninos_heroes                     float64
# ...

# %%
df.columns
# Out:
# Index(['host_id', 'host_url', 'host_name', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_listings_count',
#        'host_total_listings_count', 'd_t_museo_nacional_de_antropologia',
#        'd_t_castillo_de_chapultepec', 'd_t_palacio_de_bellas_artes',
#        'd_t_basilica_de_la_virgen_de_guadalupe', 'd_t_museo_frida_kahlo',
#        'd_t_museo_soumaya', 'd_t_museo_del_templo_mayor',
#        'd_t_zocalo_(plaza_de_la_constitucion)', 'd_t_catedral_metropolitana',
#        'd_t_palacio_nacional', 'd_t_palacio_postal',
#        'd_t_museo_de_arte_popular',
#        'd_t_mercado_de_artesanias_de_la_ciudadela',
#        'd_t_museo_memoria_y_tolerancia', 'd_t_arena_mexico',
#        'd_t_monumento_a_la_revolucion', 'd_t_museo_diego_rivera',
#        'd_t_museo_nacional_de_arte', 'd_t_museo_casa_leon_trotsky',
#        'd_t_cineteca_nacional', 'd_t_museo_franz_mayer',
#        'd_t_antiguo_colegio_de_san_ildefonso', 'd_t_museo_del_tiempo_tlalpan',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 26319 entries, 35797.0 to 9.85643e+17
# Data columns (total 44 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   host_id                                            26319 non-null  int64
#  1   host_url                                           26319 non-null  object
#  2   host_name                                          26319 non-null  object
#  3   host_response_rate                                 22694 non-null  object
#  4   host_acceptance_rate                               24030 non-null  object
#  5   host_is_superhost                                  26319 non-null  int64
#  6   host_listings_count                                26318 non-null  object
#  7   host_total_listings_count                          26318 non-null  float64
# ...

# %%
df.count()
# Out:
# host_id                                              26319
# host_url                                             26319
# host_name                                            26319
# host_response_rate                                   22694
# host_acceptance_rate                                 24030
# host_is_superhost                                    26319
# host_listings_count                                  26318
# host_total_listings_count                            26318
# d_t_museo_nacional_de_antropologia                   26318
# d_t_castillo_de_chapultepec                          26318
# d_t_palacio_de_bellas_artes                          26318
# d_t_basilica_de_la_virgen_de_guadalupe               26318
# d_t_museo_frida_kahlo                                26318
# d_t_museo_soumaya                                    26318
# d_t_museo_del_templo_mayor                           26318
# d_t_zocalo_(plaza_de_la_constitucion)                26318
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# host_response_rate                                   3625
# host_acceptance_rate                                 2289
# d_t_mercado_medellin                                    2
# d_t_monumento_a_los_ninos_heroes                        2
# d_t_museo_del_tiempo_tlalpan                            2
# d_t_monumento_a_la_independencia_(el_angel)             2
# d_t_sagrario_metropolitano                              2
# d_t_museo_de_arte_moderno                               2
# d_t_museo_universitario_arte_contemporaneo_(muac)       2
# d_t_plaza_de_las_tres_culturas                          2
# d_t_zona_arqueologica_tlatelolco                        2
# d_t_museo_jumex                                         2
# d_t_museo_tamayo                                        2
# d_t_parroquia_san_juan_bautista                         2
# d_t_museo_nacional_de_san_carlos                        2
# d_t_palacio_de_mineria                                  2
# ...

# %%
columns_nan = df.isna().sum().sort_values(ascending=False)
number_columns_nan = (columns_nan[columns_nan>0]/len(df))*100
number_columns_nan
# Out:
# host_response_rate                                   13.773320
# host_acceptance_rate                                  8.697139
# d_t_mercado_medellin                                  0.007599
# d_t_monumento_a_los_ninos_heroes                      0.007599
# d_t_museo_del_tiempo_tlalpan                          0.007599
# d_t_monumento_a_la_independencia_(el_angel)           0.007599
# d_t_sagrario_metropolitano                            0.007599
# d_t_museo_de_arte_moderno                             0.007599
# d_t_museo_universitario_arte_contemporaneo_(muac)     0.007599
# d_t_plaza_de_las_tres_culturas                        0.007599
# d_t_zona_arqueologica_tlatelolco                      0.007599
# d_t_museo_jumex                                       0.007599
# d_t_museo_tamayo                                      0.007599
# d_t_parroquia_san_juan_bautista                       0.007599
# d_t_museo_nacional_de_san_carlos                      0.007599
# ...

# %%
print("The dataset have " + str(len(number_columns_nan)) + " columns with nan values or data that needs to be analyzed and addresed")
# Out:
# The dataset have 40 columns with nan values or data that needs to be analyzed and addresed

# %%
plt.figure(figsize=(35,35))
sns.set(style='dark')
sns.heatmap(df.corr(), center=0, cmap='YlGnBu', annot=True, fmt='.2f')
plt.savefig("Correlation_matrix_with_the_original_data.pdf")
correlation_matrix = df.corr()

# %%
correlation_matrix_filtered = correlation_matrix[correlation_matrix < 0]
plt.figure(figsize=(35, 35))
sns.set(style='dark')
sns.heatmap(correlation_matrix_filtered, center=0, cmap='YlGnBu', annot=True, fmt='.2f')
plt.savefig("Correlation_matrix_with_the_original_data_lower_0_percent.pdf")

# %%
plt.scatter(df.values[:,6], df.values[:,16])
plt.show()

# %%
print(max(df.values[:,7]))
# Out:
# 2421
